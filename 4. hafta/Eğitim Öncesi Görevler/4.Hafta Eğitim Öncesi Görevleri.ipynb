# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
rehber = {"ahmet" : "0532 678 13 19", "mehmet" : "0521 478 99 00"}
isim = input("Lütfen numarasını öğrenmek istediğiniz kişinin adını girin :")
print(f"{isim.capitalize()} isimli kişinin numarası şu şekildedir: {rehber[isim]}")
# Out:
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
isimler = {"Mehmet Yağız" : {"Memleket" : "Adana",
                             "Meslek" : "Direktör",
                             "Yaş" : "40"}}
print("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini giriniz :")
x = input("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini giriniz : ")
print(f"{x} = Memleket: {isimler[x]["Memleket"]} Yaş: {isimler[x]["Yaş"]} Görev: {isimler[x]["Meslek"]}")
# Out:
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini giriniz :
# Mehmet Yağız = Memleket: Adana Yaş: 40 Görev: Direktör

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
notlar = {"Mehmet" : {"1. Sınav" : 72,
                      "2. Sınav" : 66,
                       "3. Sınav" : 48}}
isim = input("Lütfen notlarını görmek istediğiniz öğrencinin adını girin : ")
print(f"Lütfen notlarını görmek istediğiniz öğrencinin adını girin : {isim}")
print(f"1. sınav notu: {notlar[isim]["1. Sınav"]}")
print(f"2. sınav notu: {notlar[isim]["2. Sınav"]}")
print(f"3. sınav notu: {notlar[isim]["3. Sınav"]}")
print(f"Not Ortalaması: {((notlar[isim]["1. Sınav"]) + notlar[isim]["2. Sınav"] + notlar[isim]["3. Sınav"]) / 3}")
# Out:
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin : Mehmet
# 1. sınav notu: 72
# 2. sınav notu: 66
# 3. sınav notu: 48
# Not Ortalaması: 62.0

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
arabalar = ["Bmw", "Mercedes", "Opel", "Mazda"]

# 2-  Liste Kaç elemanlıdır ?
print(f"Liste {len(arabalar)} elemanlıdır.")

# 3-  Listenin ilk ve son elemanı nedir ?
print(f"Listenin ilk elemanı: {arabalar[0]}, son elemanı: {arabalar[-1]} ")

# 4-  Mazda değerini Toyota ile değiştirin.
arabalar.insert(arabalar.index("Mazda"), "Toyota")
arabalar.remove("Mazda")
print(f"Mazdanın Toyota ile değiştirilmiş hali: {arabalar}")

# 5-  Listenin -2 indeksindeki değer nedir ?
print(f"Listenin -2 indeksindeki değeri: {arabalar[-2]}")

# 6-  Listenin ilk 3 elemanını alın.
print(f"Listenin ilk 3 elemanı: {arabalar[0: 3]}")

# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
arabalar.pop() 
arabalar.pop() 
arabalar.append("Toyota")
arabalar.append("Renault")
print(f"Listenin son 2 elemanı yerine Toyota ve Renault değerlerini ekleyin: {arabalar} ")

# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
arabalar.append("Audi")
arabalar.append("Nissan")
print(f"Listenin üzerine Audi ve Nissan değerlerini ekleyin: {arabalar}")


# 9- Listenin son elemanını silin.
arabalar.pop()
print(f"Listenin son elemanını silin: {arabalar}")

# 10- Liste elemanlarını tersten yazdırınız.
arabalar.reverse()
print(f"Liste elemanlarını tersten yazdırınız: {arabalar}")

# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 
students = {"Öğrenci 1" : {"İsim" : "Yiğit Bilgi",
                           "Doğum Yılı" : 2010,
                           "1. Notu" : 70,
                           "2. Notu" : 60,
                           "3. Notu" : 70},
            "Öğrenci 2" : {"İsim" : "Sena Turan",
                           "Doğum Yılı" : 1999,
                           "1. Notu" : 80,
                           "2. Notu" : 80,
                           "3. Notu" : 70},
            "Öğrenci 3" : {"İsim" : "Ahmet Turan",
                           "Doğum Yılı" : 1998,
                           "1. Notu" : 80,
                           "2. Notu" : 70,
                           "3. Notu" : 90}}



# 12- Liste elemanlarını ekrana yazdırınız.
print(f"Listenin Elemanları : {students.items()}")



  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")
print(f"Cenk ismini listenin sonuna ekleyiniz : {names}")


# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0, "Sena")
print(f"Sena değerini listenin başına ekleyiniz: {names}")

# 15-  "Deniz" ismini listeden siliniz.,
names.remove("Deniz")
print(f"Deniz ismini listeden siliniz : {names}")


# 16-  "Ali" listenin bir elemanı mıdır ?
if("Ali" in (names)):
    print("Ali listenin bir elemanıdır.")
else:
    print("Ali listenin bir elemanı değildir.")

# 17-  Liste elemanlarını ters çevirin.
names.reverse()
print(f"Liste elemanlarını ters çevirin : {names}")

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()
print(f"Liste elemanlarını alfabetik olarak sıralayınız : {names}")


# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years.sort()
print(f" years listesini rakamsal büyüklüğe göre sıralayınız: {years}")

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
str = "Chevrolet,Dacia"
print(str.split(","))



# 21- years dizisinde kaç tane 1998 değeri vardır ?
y = years.count(1998)
print(f"years dizisinde kaç tane 1998 değeri vardır: {y}")


# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()
print(f"years dizisinin tüm elemanlarını siliniz: {years}")


# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
markalar = input("3 tane marka ismi giriniz: ")
liste = [markalar.split(" ")]
print(liste)
# Out:
# Liste 4 elemanlıdır.
# Listenin ilk elemanı: Bmw, son elemanı: Mazda
# Mazdanın Toyota ile değiştirilmiş hali: ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# Listenin -2 indeksindeki değeri: Opel
# Listenin ilk 3 elemanı: ['Bmw', 'Mercedes', 'Opel']
# Listenin son 2 elemanı yerine Toyota ve Renault değerlerini ekleyin: ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# Listenin üzerine Audi ve Nissan değerlerini ekleyin: ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi', 'Nissan']
# Listenin son elemanını silin: ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi']
# Liste elemanlarını tersten yazdırınız: ['Audi', 'Renault', 'Toyota', 'Mercedes', 'Bmw']
# Listenin Elemanları : dict_items([('Öğrenci 1', {'İsim': 'Yiğit Bilgi', 'Doğum Yılı': 2010, '1. Notu': 70, '2. Notu': 60, '3. Notu': 70}), ('Öğrenci 2', {'İsim': 'Sena Turan', 'Doğum Yılı': 1999, '1. Notu': 80, '2. Notu': 80, '3. Notu': 70}), ('Öğrenci 3', {'İsim': 'Ahmet Turan', 'Doğum Yılı': 1998, '1. Notu': 80, '2. Notu': 70, '3. Notu': 90})])
# Cenk ismini listenin sonuna ekleyiniz : ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# Sena değerini listenin başına ekleyiniz: ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# Deniz ismini listeden siliniz : ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# Ali listenin bir elemanıdır.
# Liste elemanlarını ters çevirin : ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# Liste elemanlarını alfabetik olarak sıralayınız : ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
#  years listesini rakamsal büyüklüğe göre sıralayınız: [1987, 1998, 1998, 2000]
# ['Chevrolet', 'Dacia']
# years dizisinde kaç tane 1998 değeri vardır: 2
# years dizisinin tüm elemanlarını siliniz: []
# [['nike', 'adidas', 'puma']]
